# %%
Label_Dict = {
    '01_ka': '𑌕', '02_kha': '𑌖', '03_ga': '𑌗', '04_gha': '𑌘', '05_na(01)': '𑌙', '06_ca': '𑌚', '07_cha': '𑌛', '08_ja': '𑌜', '09_jha': '𑌝', '10_na(02)': '𑌞', 
    '11_ta(01)': '𑌟', '12_tha(01)': '𑌠', '13_da': '𑌡', '14_dha(01)': '𑌢', '15_na(03)': '𑌣', '16_ta(02)': '𑌤', '17_tha(02)': '𑌥', '18_da(02)': '𑌦', '19_dha(02)': '𑌧', '20_na(04)': '𑌨', 
    '21_pa': '𑌪', '22_pha': '𑌫', '23_ba': '𑌬', '24_bha': '𑌭', '25_ma': '𑌮', '26_ya': '𑌯', '27_ra': '𑌰', '28_la(01)': '𑌲', '29_va': '𑌵', '31_sa(01)': '𑌶', 
    '32_sa(02)': '𑌷', '33_sa(03)': '𑌸', '34_ha': '𑌹', '0': '௦', '1': '௧', '2': '௨', '3': '௩', '4': '௪', '5': '௫', '6': '௬', 
    '7': '௭', '8': '௮', '9': '௯', 'bau': '𑌭𑍗', 'bhaa': '𑌭𑌾', 'chcha': '𑌚𑍍𑌚', 'ddha': '𑌦𑍍𑌧​', 'dhaa': '𑌧𑌾', 
    'dhae': '𑌦𑍇', 'dhva': '𑌦𑍍𑌵', 'dhvaa': '𑌦𑍍𑌵𑌾', 'dhya': '𑌦𑍍𑌯​', 'gaa': '𑌗𑌾', 'gee': '𑌗𑍀', 'hma': '𑌹𑍍𑌮​', 
    'jaa': '𑌜𑌾', 'jna': '𑌜𑍍𑌞', 'jya': '𑌜𑍃​', 'kaa': '𑌕𑌾', 'khi': '𑌖𑌿', 'koo': '𑌕𑍂', 'ksha': '𑌕𑍍𑌷', 
    'ktha': '𑌕𑍍𑌤​', 'kthi': '𑌕𑍍𑌤𑌿', 'lau': '𑌲𑍗', 'li': '𑌲𑌿', 'maa': '𑌮𑌾', 'mu': '𑌮𑍁', 'n': '𑌨𑍍', 
    'naa (3)': '𑌣𑌾', 'nau (3)': '𑌣𑍗', 'nca': '𑌞𑍍𑌚', 'nda': '𑌣𑍍𑌟', 'nda(1)': '𑌨𑍍𑌦', 'nea': '𑌨𑍇', 'nee': '𑌨𑍀', 
    'nga': '𑌙𑍍𑌗', 'ni': '𑌨𑌿', 'nja': '𑌞𑍍𑌜', 'nna': '𑌨𑍍𑌨​', 'nni': '𑌨𑍍𑌨𑌿', 'ntha': '𑌨𑍍𑌤', 
    'ntha(1)': '𑌨𑍍𑌥​', 'nthe': '𑌨𑍍𑌤𑍇', 'nthi': '𑌨𑍍𑌤𑌿', 'nthva': '𑌨𑍍𑌤𑍍𑌵​', 'nu': '𑌨𑍍𑌵', 'paa': '𑌪𑌾', 
    'pi': '𑌪𑌿', 'raa': '𑌰𑌾', 'rthu': '𑌰𑍍𑌤𑍁', 'ruu': '𑌰𑍂', 'rva': '𑌰𑍍𑌵​', 'rya': '𑌰𑍍𑌯​', 'saa': '𑌸𑌾', 
    'shcha': '𑌶𑍍𑌚', 'shhaa': '𑌷𑌾', 'shhta': '𑌷𑍍𑌟​', 'shhtaa': '𑌷𑍍𑌟𑌾', 'shhya': '𑌷𑍍𑌯​', 'shi': '𑌶𑌿', 
    'shii': '𑌶𑍀', 'shra': '𑌶𑍍𑌰', 'shu': '𑌶𑍁', 'shuu': '𑌶𑍂', 'soo': '𑌸𑍂', 'sri': '𑌶𑍍𑌰𑍀', 'ssa': '𑌸𑍍𑌸', 
    'stha': '𑌸𑍍𑌤​', 'sthra': '𑌸𑍍𑌤𑍍𑌰​', 'su': '𑌸𑍁', 'sya': '𑌸𑍍𑌯​', 'tea': '𑌟𑍇', 'th': '𑌤𑍍', 
    'tham': '𑌤𑌂', 'thi': '𑌤𑌿', 'thra': '𑌤𑍍𑌰​', 'thraa': '𑌤𑍍𑌰𑌾', 'thri': '𑌤𑍍𑌰𑌿', 'thu': '𑌤𑍁', 'thva': '𑌤𑍍𑌵​', 
    'ti': '𑌟𑌿', 'ttha': '𑌤𑍍𑌥', 'vaa': '𑌵𑌾', 'vi': '𑌵𑌿', 'yya':  '𑌯𑍍𑌯','vowels (1)': '𑌊', 'vowels (10)': '𑍠', 
    'vowels (11)': '𑌌', 'vowels (12)': '𑍡', 'vowels (13)': '𑌓', 'vowels (14)': '𑌉', 'vowels (2)': '𑌅', 'vowels (3)': '𑌆', 'vowels (4)': '𑌏', 'vowels (5)': '𑌐', 
    'vowels (6)': '𑌔', 'vowels (7)': '𑌇', 'vowels (8)': '𑌈', 'vowels (9)': '𑌋'
}

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
from torch.nn.functional import log_softmax
from matplotlib import pyplot as plt

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load label map used during training
base_dir = r"C:\Users\Asus-2024\Downloads\Final_proper_dataset_updated\Final_dataset\customized_train"
categories = ['Consonants', 'Numerals', 'mansample-final', 'uyirezhuthukkal']
label_names = []
for category in categories:
    category_path = os.path.join(base_dir, category)
    for subfolder in os.listdir(category_path):
        subfolder_path = os.path.join(category_path, subfolder)
        if os.path.isdir(subfolder_path) and subfolder not in label_names:
            label_names.append(subfolder)

idx2char = {i: name for i, name in enumerate(label_names)}
  # Fill this with the same label list from training
idx2char = {i: name for i, name in enumerate(label_names)}

# Model Definition (same as training)
class CNN_BiLSTM_CTC(nn.Module):
    def __init__(self, num_classes):
        super(CNN_BiLSTM_CTC, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(), nn.MaxPool2d((2, 2)),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(), nn.MaxPool2d((2, 2)),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(), nn.MaxPool2d((2, 2))
        )
        self.lstm = nn.LSTM(input_size=1024, hidden_size=512, num_layers=3,
                            bidirectional=True, batch_first=True)
        self.dropout = nn.Dropout(0.25)
        self.fc = nn.Linear(1024, num_classes + 1)

    def forward(self, x):
        x = self.cnn(x)
        x = x.permute(0, 3, 1, 2)
        x = x.reshape(x.size(0), x.size(1), -1)
        x, _ = self.lstm(x)
        x = self.dropout(x)
        x = self.fc(x)
        x = x.permute(1, 0, 2)
        return log_softmax(x, dim=2)

# Load Trained Model
model = CNN_BiLSTM_CTC(num_classes=len(label_names)).to(device)
model.load_state_dict(torch.load("cnn_bilstm_ctc_grantha_150.pth", map_location=device))
model.eval()

# Greedy Decoder
def greedy_decoder(output):
    pred = output.permute(1, 0, 2)
    pred = torch.argmax(pred, dim=2)
    decoded = []
    for p in pred:
        seq = []
        prev = -1
        for char in p:
            if char.item() != prev and char.item() != len(label_names):
                seq.append(char.item())
            prev = char.item()
        decoded.append(seq)
    return decoded

# Segment word image into characters using vertical projection
def segment_characters(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    _, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    projection = np.sum(thresh, axis=0)
    in_char = False
    start = 0
    char_images = []

    for i, val in enumerate(projection):
        if val > 0 and not in_char:
            start = i
            in_char = True
        elif val == 0 and in_char:
            end = i
            char = thresh[:, start:end]
            if end - start > 2:
                char = cv2.resize(char, (128, 32), interpolation=cv2.INTER_AREA)
                char = cv2.bitwise_not(char)
                char_images.append(char)
            in_char = False
    return char_images

# Predict a single character image
def predict_single_char(char_img):
    img = char_img.astype(np.float32) / 255.0
    img = torch.tensor(img).unsqueeze(0).unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        output = model(img)
        pred_indices = greedy_decoder(output)[0]
        pred_labels = [idx2char[idx] for idx in pred_indices]
        return pred_labels[0] if pred_labels else ''

# Predict full sequence from a word image
def predict_word_from_image(word_img_path):
    char_imgs = segment_characters(word_img_path)
    predictions = []
    for char_img in char_imgs:
        pred = predict_single_char(char_img)
        predictions.append(pred)
    return predictions

# Test
test_image_path = r"C:\Users\Asus-2024\OneDrive\Pictures\Screenshots\Screenshot 2025-04-25 075344.png"
prediction = predict_word_from_image(test_image_path)
for letter in prediction:
    # Safely convert to Grantha Unicode with fallback for unknowns
    pred_unicode = [Label_Dict.get(label, f"[{label}]") for label in prediction]


print("Predicted Output:", ''.join(pred_unicode))
# Visualize result
img = cv2.imread(test_image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

plt.axis('off')
plt.show()
# Out:
# Predicted Output: 𑌗𑌦𑍍𑌵𑌾𑌶𑍍𑌚
